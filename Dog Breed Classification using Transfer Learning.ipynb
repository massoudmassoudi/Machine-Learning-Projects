# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

import cv2
import tensorflow as tf
from tensorflow import keras
from keras import layers
from functools import partial

import warnings
warnings.filterwarnings('ignore')
AUTO = tf.data.experimental.AUTOTUNE

# %%
from zipfile import ZipFile
data_path = 'dog-breed-identification.zip'

with ZipFile(data_path, 'r') as zip:
    zip.extractall()
    print('The data set has been extracted.')
# Out:
# The data set has been extracted.

# %%
df = pd.read_csv('labels.csv')
df.head()
# Out:
#                                  id             breed
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever

# %%
df.shape
# Out:
# (10222, 2)

# %%
df['breed'].nunique()
# Out:
# 120

# %%
plt.figure(figsize=(10, 5))
df['breed'].value_counts().plot.bar()
plt.axis('off')
plt.show()

# %%
df['filepath'] = 'train/' + df['id'] + '.jpg'
df.head()
# Out:
#                                  id             breed  \
# 0  000bec180eb18c7604dcecc8fe0dba07       boston_bull
# 1  001513dfcb2ffafc82cccf4d8bbaba97             dingo
# 2  001cdf01b096e06d78e9e5112d419397          pekinese
# 3  00214f311d5d2247d5dfe4fe24b2303d          bluetick
# 4  0021f9ceb3235effd7fcde7f7538ed62  golden_retriever
#
#                                      filepath
# 0  train/000bec180eb18c7604dcecc8fe0dba07.jpg
# 1  train/001513dfcb2ffafc82cccf4d8bbaba97.jpg
# 2  train/001cdf01b096e06d78e9e5112d419397.jpg
# 3  train/00214f311d5d2247d5dfe4fe24b2303d.jpg
# 4  train/0021f9ceb3235effd7fcde7f7538ed62.jpg

# %%
plt.subplots(figsize=(10, 10))
for i in range(12):
    plt.subplot(4, 3, i+1)

    # Selecting a random image
    # index from the dataframe.
    k = np.random.randint(0, len(df))
    img = cv2.imread(df.loc[k, 'filepath'])
    plt.imshow(img)
    plt.title(df.loc[k, 'breed'])
    plt.axis('off')
plt.show()

# %%
le = LabelEncoder()
df['breed'] = le.fit_transform(df['breed'])
df.head()
# Out:
#                                  id  breed  \
# 0  000bec180eb18c7604dcecc8fe0dba07     19
# 1  001513dfcb2ffafc82cccf4d8bbaba97     37
# 2  001cdf01b096e06d78e9e5112d419397     85
# 3  00214f311d5d2247d5dfe4fe24b2303d     15
# 4  0021f9ceb3235effd7fcde7f7538ed62     49
#
#                                      filepath
# 0  train/000bec180eb18c7604dcecc8fe0dba07.jpg
# 1  train/001513dfcb2ffafc82cccf4d8bbaba97.jpg
# 2  train/001cdf01b096e06d78e9e5112d419397.jpg
# 3  train/00214f311d5d2247d5dfe4fe24b2303d.jpg
# 4  train/0021f9ceb3235effd7fcde7f7538ed62.jpg

# %%
features = df['filepath']
target = df['breed']

X_train, X_val, Y_train, Y_val = train_test_split(features, target,
                                      test_size=0.15,
                                      random_state=10)

X_train.shape, X_val.shape
# Out:
# ((8688,), (1534,))

# %%
import albumentations as A

transforms_train = A.Compose([
    A.VerticalFlip(p=0.2),
    A.HorizontalFlip(p=0.7),
    A.CoarseDropout(p=0.5),
    A.RandomGamma(p=0.5),
    A.RandomBrightnessContrast(p=1)
])

# %%
img = cv2.imread('train/00792e341f3c6eb33663e415d0715370.jpg')
plt.imshow(img)
plt.show()

# %%
augments = [A.VerticalFlip(p=1), A.HorizontalFlip(p=1),
            A.CoarseDropout(p=1), A.CLAHE(p=1)]

plt.subplots(figsize=(10, 10))
for i, aug in enumerate(augments):
    plt.subplot(2, 2, i+1)
    aug_img = aug(image=img)['image']
    plt.imshow(aug_img)
plt.show()

# %%
def aug_fn(img):
    aug_data = transforms_train(image=img)
    aug_img = aug_data['image']

    return aug_img


@tf.function
def process_data(img, label):
    aug_img = tf.numpy_function(aug_fn,
                                [img],
                                Tout=tf.float32)

    return img, label


def decode_image(filepath, label=None):

    img = tf.io.read_file(filepath)
    img = tf.image.decode_jpeg(img)
    img = tf.image.resize(img, [128, 128])
    img = tf.cast(img, tf.float32) / 255.0

    if label == None:
        return img

    return img, tf.one_hot(indices=label,
                           depth=120,
                           dtype=tf.float32)

# %%
train_ds = (
    tf.data.Dataset
    .from_tensor_slices((X_train, Y_train))
    .map(decode_image, num_parallel_calls=AUTO)
    .map(partial(process_data), num_parallel_calls=AUTO)
    .batch(32)
    .prefetch(AUTO)
)

val_ds = (
    tf.data.Dataset
    .from_tensor_slices((X_val, Y_val))
    .map(decode_image, num_parallel_calls=AUTO)
    .batch(32)
    .prefetch(AUTO)
)

# %%
for img, label in train_ds.take(1):
  print(img.shape, label.shape)
# Out:
# (32, 128, 128, 3) (32, 120)

# %%
from tensorflow.keras.applications.inception_v3 import InceptionV3

pre_trained_model = InceptionV3(
    input_shape=(128, 128, 3),
    weights='imagenet',
    include_top=False
)

# %%
len(pre_trained_model.layers)
# Out:
# 311

# %%
for layer in pre_trained_model.layers: 
  layer.trainable = False

last_layer = pre_trained_model.get_layer('mixed7') 
# Access the output shape from the output tensor of the layer
print('last layer output shape: ', last_layer.output.shape) 
last_output = last_layer.output
# Out:
# last layer output shape:  (None, 6, 6, 768)

# %%
# Model Architecture
x = layers.Flatten()(last_output)
x = layers.Dense(256, activation='relu')(x)
x = layers.BatchNormalization()(x)
x = layers.Dense(256, activation='relu')(x)
x = layers.Dropout(0.3)(x)
x = layers.BatchNormalization()(x)
output = layers.Dense(120, activation='softmax')(x)

model = keras.Model(pre_trained_model.input, output)

# Model Compilation
model.compile(
    optimizer='adam',
    loss=keras.losses.CategoricalCrossentropy(from_logits=True),
    metrics=[tf.keras.metrics.AUC()]
)

# %%
from keras.callbacks import EarlyStopping, ReduceLROnPlateau

class myCallback(tf.keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs={}):
        if logs.get('val_auc') is not None and logs.get('val_auc') > 0.99:
            print('\n Validation accuracy has reached upto 90% so, stopping further training.')
            self.model.stop_training = True

es = EarlyStopping(patience=3,
                monitor='val_auc',
                restore_best_weights=True,
                mode='max')

lr = ReduceLROnPlateau(monitor='val_loss',
                    patience=2,
                    factor=0.5,
                    verbose=1)

# %%
history = model.fit(train_ds,
                    validation_data=val_ds,
                    epochs=50, 
                    verbose=1,
                    callbacks=[es, lr, myCallback()])
# Out:
# Epoch 1/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 294s 1s/step - auc_1: 0.7210 - loss: 4.3507 - val_auc_1: 0.9387 - val_loss: 2.5846 - learning_rate: 0.0010
# Epoch 2/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 284s 1s/step - auc_1: 0.9646 - loss: 2.1828 - val_auc_1: 0.9436 - val_loss: 2.3423 - learning_rate: 0.0010
# Epoch 3/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 281s 1s/step - auc_1: 0.9916 - loss: 1.1866 - val_auc_1: 0.9301 - val_loss: 2.4033 - learning_rate: 0.0010
# Epoch 4/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 990ms/step - auc_1: 0.9994 - loss: 0.4796
# Epoch 4: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 307s 1s/step - auc_1: 0.9994 - loss: 0.4793 - val_auc_1: 0.9178 - val_loss: 2.4934 - learning_rate: 0.0010
# Epoch 5/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 311s 1s/step - auc_1: 1.0000 - loss: 0.1735 - val_auc_1: 0.9292 - val_loss: 2.3092 - learning_rate: 5.0000e-04
# Epoch 6/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 282s 1s/step - auc_1: 1.0000 - loss: 0.0748 - val_auc_1: 0.9266 - val_loss: 2.3284 - learning_rate: 5.0000e-04
# Epoch 7/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 900ms/step - auc_1: 0.9998 - loss: 0.0509
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 283s 1s/step - auc_1: 0.9998 - loss: 0.0508 - val_auc_1: 0.9260 - val_loss: 2.3336 - learning_rate: 5.0000e-04
# Epoch 8/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 328s 1s/step - auc_1: 1.0000 - loss: 0.0311 - val_auc_1: 0.9284 - val_loss: 2.3194 - learning_rate: 2.5000e-04
# Epoch 9/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 931ms/step - auc_1: 1.0000 - loss: 0.0242
# Epoch 9: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 348s 1s/step - auc_1: 1.0000 - loss: 0.0242 - val_auc_1: 0.9268 - val_loss: 2.3264 - learning_rate: 2.5000e-04
# Epoch 10/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 330s 1s/step - auc_1: 1.0000 - loss: 0.0195 - val_auc_1: 0.9264 - val_loss: 2.3259 - learning_rate: 1.2500e-04
# Epoch 11/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - auc_1: 1.0000 - loss: 0.0171
# Epoch 11: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 331s 1s/step - auc_1: 1.0000 - loss: 0.0171 - val_auc_1: 0.9253 - val_loss: 2.3331 - learning_rate: 1.2500e-04
# Epoch 12/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 330s 1s/step - auc_1: 1.0000 - loss: 0.0153 - val_auc_1: 0.9246 - val_loss: 2.3358 - learning_rate: 6.2500e-05
# Epoch 13/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 951ms/step - auc_1: 1.0000 - loss: 0.0142
# Epoch 13: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 353s 1s/step - auc_1: 1.0000 - loss: 0.0142 - val_auc_1: 0.9258 - val_loss: 2.3345 - learning_rate: 6.2500e-05
# Epoch 14/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 305s 1s/step - auc_1: 1.0000 - loss: 0.0141 - val_auc_1: 0.9246 - val_loss: 2.3365 - learning_rate: 3.1250e-05
# Epoch 15/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 954ms/step - auc_1: 1.0000 - loss: 0.0129
# Epoch 15: ReduceLROnPlateau reducing learning rate to 1.5625000742147677e-05.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 300s 1s/step - auc_1: 1.0000 - loss: 0.0129 - val_auc_1: 0.9252 - val_loss: 2.3383 - learning_rate: 3.1250e-05
# Epoch 16/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 420s 1s/step - auc_1: 1.0000 - loss: 0.0116 - val_auc_1: 0.9249 - val_loss: 2.3402 - learning_rate: 1.5625e-05
# Epoch 17/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 992ms/step - auc_1: 1.0000 - loss: 0.0122
# Epoch 17: ReduceLROnPlateau reducing learning rate to 7.812500371073838e-06.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 312s 1s/step - auc_1: 1.0000 - loss: 0.0122 - val_auc_1: 0.9249 - val_loss: 2.3406 - learning_rate: 1.5625e-05
# Epoch 18/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 332s 1s/step - auc_1: 1.0000 - loss: 0.0116 - val_auc_1: 0.9252 - val_loss: 2.3388 - learning_rate: 7.8125e-06
# Epoch 19/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - auc_1: 1.0000 - loss: 0.0113
# Epoch 19: ReduceLROnPlateau reducing learning rate to 3.906250185536919e-06.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 380s 1s/step - auc_1: 1.0000 - loss: 0.0113 - val_auc_1: 0.9256 - val_loss: 2.3402 - learning_rate: 7.8125e-06
# Epoch 20/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 325s 1s/step - auc_1: 1.0000 - loss: 0.0107 - val_auc_1: 0.9249 - val_loss: 2.3392 - learning_rate: 3.9063e-06
# Epoch 21/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - auc_1: 1.0000 - loss: 0.0114
# Epoch 21: ReduceLROnPlateau reducing learning rate to 1.9531250927684596e-06.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 322s 1s/step - auc_1: 1.0000 - loss: 0.0114 - val_auc_1: 0.9247 - val_loss: 2.3407 - learning_rate: 3.9063e-06
# Epoch 22/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 311s 1s/step - auc_1: 1.0000 - loss: 0.0109 - val_auc_1: 0.9253 - val_loss: 2.3401 - learning_rate: 1.9531e-06
# Epoch 23/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 981ms/step - auc_1: 1.0000 - loss: 0.0107
# Epoch 23: ReduceLROnPlateau reducing learning rate to 9.765625463842298e-07.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 310s 1s/step - auc_1: 1.0000 - loss: 0.0107 - val_auc_1: 0.9247 - val_loss: 2.3400 - learning_rate: 1.9531e-06
# Epoch 24/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 315s 1s/step - auc_1: 1.0000 - loss: 0.0112 - val_auc_1: 0.9247 - val_loss: 2.3417 - learning_rate: 9.7656e-07
# Epoch 25/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - auc_1: 1.0000 - loss: 0.0106
# Epoch 25: ReduceLROnPlateau reducing learning rate to 4.882812731921149e-07.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 334s 1s/step - auc_1: 1.0000 - loss: 0.0106 - val_auc_1: 0.9246 - val_loss: 2.3413 - learning_rate: 9.7656e-07
# Epoch 26/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 491s 2s/step - auc_1: 1.0000 - loss: 0.0107 - val_auc_1: 0.9249 - val_loss: 2.3423 - learning_rate: 4.8828e-07
# Epoch 27/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - auc_1: 1.0000 - loss: 0.0112
# Epoch 27: ReduceLROnPlateau reducing learning rate to 2.4414063659605745e-07.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 753s 3s/step - auc_1: 1.0000 - loss: 0.0112 - val_auc_1: 0.9250 - val_loss: 2.3413 - learning_rate: 4.8828e-07
# Epoch 28/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 722s 2s/step - auc_1: 1.0000 - loss: 0.0111 - val_auc_1: 0.9246 - val_loss: 2.3422 - learning_rate: 2.4414e-07
# Epoch 29/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - auc_1: 1.0000 - loss: 0.0106
# Epoch 29: ReduceLROnPlateau reducing learning rate to 1.2207031829802872e-07.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 614s 2s/step - auc_1: 1.0000 - loss: 0.0106 - val_auc_1: 0.9249 - val_loss: 2.3418 - learning_rate: 2.4414e-07
# Epoch 30/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 988s 4s/step - auc_1: 1.0000 - loss: 0.0106 - val_auc_1: 0.9250 - val_loss: 2.3415 - learning_rate: 1.2207e-07
# Epoch 31/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - auc_1: 1.0000 - loss: 0.0111
# Epoch 31: ReduceLROnPlateau reducing learning rate to 6.103515914901436e-08.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1140s 4s/step - auc_1: 1.0000 - loss: 0.0111 - val_auc_1: 0.9253 - val_loss: 2.3415 - learning_rate: 1.2207e-07
# Epoch 32/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 1068s 4s/step - auc_1: 1.0000 - loss: 0.0115 - val_auc_1: 0.9244 - val_loss: 2.3414 - learning_rate: 6.1035e-08
# Epoch 33/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - auc_1: 1.0000 - loss: 0.0109
# Epoch 33: ReduceLROnPlateau reducing learning rate to 3.051757957450718e-08.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 513s 2s/step - auc_1: 1.0000 - loss: 0.0109 - val_auc_1: 0.9247 - val_loss: 2.3415 - learning_rate: 6.1035e-08
# Epoch 34/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 513s 2s/step - auc_1: 1.0000 - loss: 0.0109 - val_auc_1: 0.9246 - val_loss: 2.3412 - learning_rate: 3.0518e-08
# Epoch 35/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - auc_1: 1.0000 - loss: 0.0115
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.525878978725359e-08.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 574s 2s/step - auc_1: 1.0000 - loss: 0.0115 - val_auc_1: 0.9246 - val_loss: 2.3420 - learning_rate: 3.0518e-08
# Epoch 36/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 672s 2s/step - auc_1: 1.0000 - loss: 0.0103 - val_auc_1: 0.9246 - val_loss: 2.3417 - learning_rate: 1.5259e-08
# Epoch 37/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - auc_1: 1.0000 - loss: 0.0109
# Epoch 37: ReduceLROnPlateau reducing learning rate to 7.629394893626795e-09.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 336s 1s/step - auc_1: 1.0000 - loss: 0.0109 - val_auc_1: 0.9250 - val_loss: 2.3418 - learning_rate: 1.5259e-08
# Epoch 38/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 389s 1s/step - auc_1: 1.0000 - loss: 0.0108 - val_auc_1: 0.9253 - val_loss: 2.3419 - learning_rate: 7.6294e-09
# Epoch 39/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - auc_1: 1.0000 - loss: 0.0108
# Epoch 39: ReduceLROnPlateau reducing learning rate to 3.814697446813398e-09.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 424s 1s/step - auc_1: 1.0000 - loss: 0.0108 - val_auc_1: 0.9249 - val_loss: 2.3406 - learning_rate: 7.6294e-09
# Epoch 40/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 410s 1s/step - auc_1: 1.0000 - loss: 0.0106 - val_auc_1: 0.9253 - val_loss: 2.3413 - learning_rate: 3.8147e-09
# Epoch 41/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - auc_1: 1.0000 - loss: 0.0116
# Epoch 41: ReduceLROnPlateau reducing learning rate to 1.907348723406699e-09.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 339s 1s/step - auc_1: 1.0000 - loss: 0.0116 - val_auc_1: 0.9250 - val_loss: 2.3420 - learning_rate: 3.8147e-09
# Epoch 42/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 383s 1s/step - auc_1: 1.0000 - loss: 0.0108 - val_auc_1: 0.9250 - val_loss: 2.3406 - learning_rate: 1.9073e-09
# Epoch 43/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - auc_1: 1.0000 - loss: 0.0111
# Epoch 43: ReduceLROnPlateau reducing learning rate to 9.536743617033494e-10.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 365s 1s/step - auc_1: 1.0000 - loss: 0.0111 - val_auc_1: 0.9250 - val_loss: 2.3413 - learning_rate: 1.9073e-09
# Epoch 44/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 378s 1s/step - auc_1: 1.0000 - loss: 0.0107 - val_auc_1: 0.9250 - val_loss: 2.3423 - learning_rate: 9.5367e-10
# Epoch 45/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - auc_1: 1.0000 - loss: 0.0105
# Epoch 45: ReduceLROnPlateau reducing learning rate to 4.768371808516747e-10.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 409s 1s/step - auc_1: 1.0000 - loss: 0.0105 - val_auc_1: 0.9246 - val_loss: 2.3423 - learning_rate: 9.5367e-10
# Epoch 46/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - auc_1: 1.0000 - loss: 0.0106
# Epoch 47: ReduceLROnPlateau reducing learning rate to 2.3841859042583735e-10.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 369s 1s/step - auc_1: 1.0000 - loss: 0.0106 - val_auc_1: 0.9250 - val_loss: 2.3409 - learning_rate: 4.7684e-10
# Epoch 48/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 342s 1s/step - auc_1: 1.0000 - loss: 0.0112 - val_auc_1: 0.9246 - val_loss: 2.3426 - learning_rate: 2.3842e-10
# Epoch 49/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - auc_1: 1.0000 - loss: 0.0114
# Epoch 49: ReduceLROnPlateau reducing learning rate to 1.1920929521291868e-10.
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 335s 1s/step - auc_1: 1.0000 - loss: 0.0114 - val_auc_1: 0.9247 - val_loss: 2.3421 - learning_rate: 2.3842e-10
# Epoch 50/50
# 272/272 ━━━━━━━━━━━━━━━━━━━━ 405s 1s/step - auc_1: 1.0000 - loss: 0.0109 - val_auc_1: 0.9249 - val_loss: 2.3413 - learning_rate: 1.1921e-10

# %%
history_df = pd.DataFrame(history.history)
history_df.loc[:, ['loss', 'val_loss']].plot()
history_df.loc[:, ['auc_1', 'val_auc_1']].plot()
plt.show()
